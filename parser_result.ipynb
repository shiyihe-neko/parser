# %%
import pandas as pd


parser_json = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_writing_config/parser_result_json.csv')
parser_jsonc = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_writing_config/parser_result_jsonc.csv')
parser_json5 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_writing_config/parser_result_json5.csv')
parser_hjson = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_writing_config/parser_result_hjson.csv')
parser_xml = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_writing_config/parser_result_xml.csv')
parser_yaml = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_writing_config/parser_result_yaml.csv')
parser_toml = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_writing_config/parser_result_toml.csv')

# %%
parser_hjson['valid_loose'] = parser_hjson['valid_strict']
parser_hjson
# Out:
#                participantId format  valid_strict  valid_loose
# 0   680ebf035ab59d342f31726e  hjson          True         True
# 1   65583ffa38bfc41805a553cd  hjson         False        False
# 2   6717980047b565ab5b849317  hjson          True         True
# 3   67d2a409ab3638e33fc417b9  hjson         False        False
# 4   66ec8f7ce843d25227820f97  hjson         False        False
# 5   67792abbab2fa21bf3644c09  hjson         False        False
# 6   616e5ae706e970fe0aff99b6  hjson          True         True
# 7   660eafee7515c432e850362d  hjson         False        False
# 8   65fae23bd06ae76bcc297e8b  hjson         False        False
# 9   61601e9a6b8306196d2a129c  hjson         False        False
# 10  65fad6c874ac75642ffc254b  hjson         False        False
# 11  6094ce8d0764c24f352d1fe5  hjson         False        False
# 12  67d0088c269b3e96d9ba6019  hjson         False        False
# 13  678a94ff1cf9f0775cb89e69  hjson          True         True
# ...

# %%
import pandas as pd

# 假设你有多个 df：df1, df2, df3...
all_dfs = [parser_json, parser_jsonc, parser_json5, parser_hjson, parser_xml, parser_toml, parser_yaml]

# 纵向拼接，并重建索引
combined = pd.concat(all_dfs, axis=0, ignore_index=True)
combined['type']='config'
combined['task']='writing'
combined.to_csv('/Users/shiyi.he/Desktop/PARSER/config_writing_parser_result.csv', index=False)
combined
# Out:
#                 participantId format  valid_strict  valid_loose    type  \
# 0    670f9ddb0e32533c222c3031   json         False        False  config
# 1    671bdd06525adeea062a1d73   json         False        False  config
# 2    66912d7bf9d35c08f6919958   json         False        False  config
# 3    6818ca1523ece90f671e3601   json         False        False  config
# 4    6680d2279263349cc005956a   json          True         True  config
# ..                        ...    ...           ...          ...     ...
# 102  669284eabea5b8c9655927da   yaml         False        False  config
# 103  6715c7aedee148c65c10509c   yaml          True         True  config
# 104  678526627e48ded12935af38   yaml         False        False  config
# 105  6738d09a032bf7224008ce7e   yaml         False        False  config
# 106  67d24179c5bd87691f1fe036   yaml          True         True  config
#
#         task
# 0    writing
# 1    writing
# 2    writing
# 3    writing
# 4    writing
# ..       ...
# ...

# %%
import pandas as pd


parser_json_1 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_json_1.csv')
parser_json_2 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_json_2.csv')
parser_json_3 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_json_3.csv')
parser_json_4 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_json_4.csv')

parser_jsonc_1 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_jsonc_1.csv')
parser_jsonc_2 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_jsonc_2.csv')
parser_jsonc_3 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_jsonc_3.csv')
parser_jsonc_4 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_jsonc_4.csv')

parser_json5_1 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_json5_1.csv')
parser_json5_2 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_json5_2.csv')
parser_json5_3 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_json5_3.csv')
parser_json5_4 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_json5_4.csv')

parser_hjson_1 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_hjson_1.csv')
parser_hjson_2 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_hjson_2.csv')
parser_hjson_3 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_hjson_3.csv')
parser_hjson_4 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_hjson_4.csv')

parser_xml_1 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_xml_1.csv')
parser_xml_2 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_xml_2.csv')
parser_xml_3 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_xml_3.csv')
parser_xml_4 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_xml_4.csv')

parser_toml_1 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_toml_1.csv')
parser_toml_2 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_toml_2.csv')
parser_toml_3 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_toml_3.csv')
parser_toml_4 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_toml_4.csv')

parser_yaml_1 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_yaml_1.csv')
parser_yaml_2 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_yaml_2.csv')
parser_yaml_3 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_yaml_3.csv')
parser_yaml_4 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_yaml_4.csv')

parser_toml_py_1 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_toml_py_1.csv')
parser_toml_py_2 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_toml_py_2.csv')
parser_toml_py_3 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_toml_py_3.csv')
parser_toml_py_4 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_toml_py_4.csv')

parser_yaml_py_1 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_yaml_py_1.csv')
parser_yaml_py_2 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_yaml_py_2.csv')
parser_yaml_py_3 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_yaml_py_3.csv')
parser_yaml_py_4 = pd.read_csv('/Users/shiyi.he/Desktop/PARSER/parser_result_data/result_modifying_config/parser_result_yaml_py_4.csv')

parser_hjson_1['valid_loose'] = parser_hjson_1['valid_strict']
parser_hjson_2['valid_loose'] = parser_hjson_2['valid_strict']
parser_hjson_3['valid_loose'] = parser_hjson_3['valid_strict']
parser_hjson_4['valid_loose'] = parser_hjson_4['valid_strict']
parser_hjson_1
# Out:
#                participantId format  valid_strict  valid_loose
# 0   680ebf035ab59d342f31726e  hjson          True         True
# 1   65583ffa38bfc41805a553cd  hjson          True         True
# 2   6717980047b565ab5b849317  hjson          True         True
# 3   66ec8f7ce843d25227820f97  hjson          True         True
# 4   67792abbab2fa21bf3644c09  hjson          True         True
# 5   616e5ae706e970fe0aff99b6  hjson          True         True
# 6   660eafee7515c432e850362d  hjson          True         True
# 7   65fae23bd06ae76bcc297e8b  hjson          True         True
# 8   61601e9a6b8306196d2a129c  hjson          True         True
# 9   65fad6c874ac75642ffc254b  hjson          True         True
# 10  6094ce8d0764c24f352d1fe5  hjson          True         True
# 11  678a94ff1cf9f0775cb89e69  hjson          True         True
# 12  62d6d87d91cf24a3c1c0f10c  hjson          True         True

# %%
parser_json_1['task']='modifying_1'
parser_json_2['task']='modifying_2'
parser_json_3['task']='modifying_3'
parser_json_4['task']='modifying_4'
parser_jsonc_1['task']='modifying_1'
parser_jsonc_2['task']='modifying_2'
parser_jsonc_3['task']='modifying_3'
parser_jsonc_4['task']='modifying_4'
parser_json5_1['task']='modifying_1'
parser_json5_2['task']='modifying_2'
parser_json5_3['task']='modifying_3'
parser_json5_4['task']='modifying_4'
parser_hjson_1['task']='modifying_1'
parser_hjson_2['task']='modifying_2'
parser_hjson_3['task']='modifying_3'
parser_hjson_4['task']='modifying_4'
parser_xml_1['task']='modifying_1'
parser_xml_2['task']='modifying_2'
parser_xml_3['task']='modifying_3'
parser_xml_4['task']='modifying_4'
parser_yaml_1['task']='modifying_1'
parser_yaml_2['task']='modifying_2'
parser_yaml_3['task']='modifying_3'
parser_yaml_4['task']='modifying_4'
parser_toml_1['task']='modifying_1'
parser_toml_2['task']='modifying_2'
parser_toml_3['task']='modifying_3'
parser_toml_4['task']='modifying_4'

# %%
import pandas as pd

# 假设你有多个 df：df1, df2, df3...
all_dfs = [parser_json_1, parser_json_2, parser_json_3, parser_json_4,parser_jsonc_1, parser_jsonc_2, parser_jsonc_3, parser_jsonc_4,
parser_json5_1, parser_json5_2, parser_json5_3, parser_json5_4,
parser_hjson_1, parser_hjson_2, parser_hjson_3, parser_hjson_4,
parser_xml_1, parser_xml_2, parser_xml_3, parser_xml_4,
parser_toml_1, parser_toml_2, parser_toml_3, parser_toml_4,
parser_yaml_1, parser_yaml_2, parser_yaml_3, parser_yaml_4]

# 纵向拼接，并重建索引
combined = pd.concat(all_dfs, axis=0, ignore_index=True)
combined['type']='config'
combined.to_csv('/Users/shiyi.he/Desktop/PARSER/config_modifying_parser_result.csv', index=False)
combined
# Out:
#                 participantId format  valid_strict  valid_loose         task  \
# 0    671bdd06525adeea062a1d73   json          True         True  modifying_1
# 1    6818ca1523ece90f671e3601   json         False        False  modifying_1
# 2    6680d2279263349cc005956a   json          True         True  modifying_1
# 3    6081728972120aa7f9685791   json          True         True  modifying_1
# 4    675aaf0eb1b401136f37c475   json          True         True  modifying_1
# ..                        ...    ...           ...          ...          ...
# 380  669284eabea5b8c9655927da   yaml          True         True  modifying_4
# 381  6715c7aedee148c65c10509c   yaml          True         True  modifying_4
# 382  678526627e48ded12935af38   yaml          True         True  modifying_4
# 383  6738d09a032bf7224008ce7e   yaml         False        False  modifying_4
# 384  67d24179c5bd87691f1fe036   yaml          True         True  modifying_4
#
#        type
# 0    config
# 1    config
# ...

# %%
combined['type']='config'
combined['task']='writing'
combined.to_csv('/Users/shiyi.he/Desktop/PARSER/config_writing_parser_result.csv', index=False)
combined
# Out:
#                 participantId format  valid_strict  valid_loose    type  \
# 0    670f9ddb0e32533c222c3031   json         False        False  config
# 1    671bdd06525adeea062a1d73   json         False        False  config
# 2    66912d7bf9d35c08f6919958   json         False        False  config
# 3    6818ca1523ece90f671e3601   json         False        False  config
# 4    6680d2279263349cc005956a   json          True         True  config
# ..                        ...    ...           ...          ...     ...
# 102  669284eabea5b8c9655927da   yaml         False        False  config
# 103  6715c7aedee148c65c10509c   yaml          True         True  config
# 104  678526627e48ded12935af38   yaml         False        False  config
# 105  6738d09a032bf7224008ce7e   yaml         False        False  config
# 106  67d24179c5bd87691f1fe036   yaml          True         True  config
#
#         task
# 0    writing
# 1    writing
# 2    writing
# 3    writing
# 4    writing
# ..       ...
# ...
